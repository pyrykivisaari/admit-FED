# %% [markdown]
# # Example: Nonlocal densities of states
#
# Here, we calculate...

# %%
import example_gan_led_GF
# Out:
# Solved for kx= 3.54179348446185e-09
# Solved for kx= 0.05932203738006818
# Solved for kx= 0.11864407121834288
# Solved for kx= 0.17796610505661753
# Solved for kx= 0.23728813889489225
# Solved for kx= 0.2966101727331669
# Solved for kx= 0.3559322065714416
# Solved for kx= 0.4152542404097163
# Solved for kx= 0.47457627424799104
# Solved for kx= 0.5338983080862657
# Solved for kx= 0.5932203419245404
# Solved for kx= 0.6525423757628152
# Solved for kx= 0.7118644096010899
# Solved for kx= 0.7711864434393645
# Solved for kx= 0.8305084772776392
# Solved for kx= 0.8898305111159139
# Solved for kx= 0.9491525449541887
# Solved for kx= 1.0084745787924634
# Solved for kx= 1.067796612630738
# Solved for kx= 1.1271186464690128
# Solved for kx= 1.1864406803072873
# Solved for kx= 1.245762714145562
# Solved for kx= 1.3050847479838368
# Solved for kx= 1.3644067818221115
# Solved for kx= 1.423728815660386
# Solved for kx= 1.483050849498661
# Solved for kx= 1.5423728833369355
# Solved for kx= 1.6016949171752104
# Solved for kx= 1.661016951013485
# Solved for kx= 1.7203389848517598
# Solved for kx= 1.7796610186900343
# Solved for kx= 1.838983052528309
# Solved for kx= 1.8983050863665838
# Solved for kx= 1.9576271202048583
# Solved for kx= 2.0169491540431332
# Solved for kx= 2.0762711878814075
# Solved for kx= 2.1355932217196827
# Solved for kx= 2.194915255557957
# Solved for kx= 2.254237289396232
# Solved for kx= 2.3135593232345064
# Solved for kx= 2.372881357072781
# Solved for kx= 2.4322033909110554
# Solved for kx= 2.4915254247493306
# Solved for kx= 2.5508474585876053
# Solved for kx= 2.6101694924258796
# Solved for kx= 2.6694915262641543
# Solved for kx= 2.7288135601024295
# Solved for kx= 2.788135593940704
# Solved for kx= 2.8474576277789785
# Solved for kx= 2.906779661617253
# Solved for kx= 2.966101695455528
# Solved for kx= 3.025423729293802
# Solved for kx= 3.0847457631320774
# Solved for kx= 3.144067796970352
# Solved for kx= 3.203389830808627
# Solved for kx= 3.262711864646901
# Solved for kx= 3.322033898485176
# Solved for kx= 3.381355932323451
# Solved for kx= 3.4406779661617257
# Solved for kx= 3.5

# %% [markdown]
# # Example: reflection coefficient calculation
#
# Here, we calculate...

# %%
import example_reflectivity
# Out:
# Solved for L_gaas= 10  nm
# Solved for L_gaas= 20  nm
# Solved for L_gaas= 30  nm
# Solved for L_gaas= 40  nm
# Solved for L_gaas= 50  nm

# %% [markdown]
# # Example: emission of a semiconductor layer
#
# Here, we calculate...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image = mpimg.imread("images/example_emission.png")
fig1, ax1 = plt.subplots()
ax1.imshow(image)
ax1.set_axis_off()
plt.show()

# %%
import example_emission
# Out:
# Solving for E = 1.41 eV...
# Solving for E = 1.42 eV...
# Solving for E = 1.4242857142857142 eV...
# Solving for E = 1.4285714285714286 eV...
# Solving for E = 1.4328571428571428 eV...
# Solving for E = 1.437142857142857 eV...
# Solving for E = 1.4414285714285713 eV...
# Solving for E = 1.4457142857142857 eV...
# Solving for E = 1.45 eV...
# Solving for E = 1.4542857142857142 eV...
# Solving for E = 1.4585714285714286 eV...
# Solving for E = 1.4628571428571429 eV...
# Solving for E = 1.467142857142857 eV...
# Solving for E = 1.4714285714285713 eV...
# Solving for E = 1.4757142857142858 eV...
# Solving for E = 1.48 eV...
# Solving for E = 1.52 eV...
# Solving for E = 1.56 eV...
# Solving for E = 1.6 eV...
# Emission power:  (98.986322626452+0j) W/cm2

# %% [markdown]
# # Example: Optical transport in an intracavity structure
#
# Here, we calculate...

# %%
image = mpimg.imread("images/example_intracavity_transport.png")
fig2, ax2 = plt.subplots()
ax2.imshow(image)
ax2.set_axis_off()
plt.show()

# %%
import example_intracavity_transport
# Out:
# Solving for E = 1.41 eV...
# Solving for E = 1.42 eV...
# Solving for E = 1.4242857142857142 eV...
# Solving for E = 1.4285714285714286 eV...
# Solving for E = 1.4328571428571428 eV...
# Solving for E = 1.437142857142857 eV...
# Solving for E = 1.4414285714285713 eV...
# Solving for E = 1.4457142857142857 eV...
# Solving for E = 1.45 eV...
# Solving for E = 1.4542857142857142 eV...
# Solving for E = 1.4585714285714286 eV...
# Solving for E = 1.4628571428571429 eV...
# Solving for E = 1.467142857142857 eV...
# Solving for E = 1.4714285714285713 eV...
# Solving for E = 1.4757142857142858 eV...
# Solving for E = 1.48 eV...
# Solving for E = 1.52 eV...
# Solving for E = 1.56 eV...
# Solving for E = 1.6 eV...
# Emission power:  (4.7808050842235685+0j) W/cm2
# Absorption power:  (-4.332897761385577+0j) W/cm2
# Energy transfer efficiency: (0.9063113189207262-0j)
